# %% [markdown]
# # 01 Data Analysis
# Bu notebook veri seti yapısını, sınıf dağılımını ve örnek görüntüleri üretmek için `src` modüllerini kullanır.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
from src.dataset import build_data_bundle
bundle = build_data_bundle()
bundle.train_counts, bundle.test_counts, bundle.split_sizes
