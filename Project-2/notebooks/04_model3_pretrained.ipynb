# %% [markdown]
# # 04 Model 3 Transfer Learning
# ResNet18 tabanlı hazır mimarinin son katmanının veri setine uyarlanması.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
from src.models.model3_transfer import build_transfer_model
model = build_transfer_model(num_classes=6, pretrained=False)
model
