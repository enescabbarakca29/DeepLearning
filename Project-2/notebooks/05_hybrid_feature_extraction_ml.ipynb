# %% [markdown]
# # 05 Hybrid Feature Extraction + Classical ML
# CNN öznitelik çıkarımı ve Logistic Regression ile hibrit yaklaşım.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
from src.models.model3_transfer import build_feature_extractor
feature_extractor = build_feature_extractor(pretrained=False)
feature_extractor
