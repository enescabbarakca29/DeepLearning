# %% [markdown]
# # 02 Model 1 LeNet-Like
# LeNet-benzeri CNN modelinin tanımı ve eğitim akışı.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
from src.models.model1_lenet_like import LeNetLikeCNN
model = LeNetLikeCNN(num_classes=6)
model
