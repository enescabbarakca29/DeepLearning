# %% [markdown]
# # 06 Comparison and Visualizations
# Karşılaştırma tablosu ve çıktı dosyalarının okunması.

# %%
from pathlib import Path
import pandas as pd
comparison_path = Path.cwd().parent / 'outputs' / 'metrics' / 'comparison_metrics.csv'
if comparison_path.exists():
    print(pd.read_csv(comparison_path))
else:
    print('Önce python main.py çalıştırılmalıdır.')
