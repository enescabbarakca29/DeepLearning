# %% [markdown]
# # 03 Model 2 Improved CNN
# BatchNorm ve Dropout içeren iyileştirilmiş CNN modelinin kullanımı.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
from src.models.model2_improved_cnn import ImprovedCNN
model = ImprovedCNN(num_classes=6)
model
